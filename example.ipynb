# %%
import pickle

with open("ml_model/feature_columns.pkl", "rb") as f:
    cols = pickle.load(f)

print(cols)
# Out:
# ['Vehicle_Type', 'Year_of_Manufacture', 'Route_Info', 'Weather_Conditions', 'Road_Conditions', 'Vehicle_Runtime_Hours', 'Load_Capacity', 'Vehicle_Load', 'Motor_Temperature', 'Tire_Pressure', 'Battery_Health', 'Motor_Vibration', 'Failure_History', 'Anomalies_Detected', 'Diagnostic_Trouble_Code_Count', 'Brake_Condition', 'Vehicle_Age', 'Load_Utilization', 'Operational_Stress', 'Brake_Risk']
